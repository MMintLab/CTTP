# %%
import torch
import os
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
# Select results comparison
dataset = 'stl_10'

# %%
results_path = '/home/samanta/CMTJE/checkpoints/stl_10/barlow_twins/dataset_2_run_'
split = 'test'
embeddings, labels, sensor_array = load_embeddings(results_path, split=split, dataset='stl')
tsne_embeddings = apply_tsne_3d(embeddings)

# %%
from mpl_toolkits.mplot3d import Axes3D

# Assuming tsne_embeddings is now an array of shape (n_samples, 3)
unique_labels = np.unique(labels)
colors = plt.cm.tab10(np.linspace(0, 1, len(unique_labels)))
label_to_color = dict(zip(unique_labels, colors))

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

for label in unique_labels:
    idx = labels == label
    ax.scatter(tsne_embeddings[idx, 0], tsne_embeddings[idx, 1], tsne_embeddings[idx, 2], c=[label_to_color[label]], label=label)

plt.legend(markerscale=1)
plt.title('3D t-SNE visualization of embeddings')
ax.set_xlabel('t-SNE 1')
ax.set_ylabel('t-SNE 2')
ax.set_zlabel('t-SNE 3')
plt.show()

# %%
unique_labels = np.unique(labels)
colors = plt.cm.tab10(np.linspace(0, 1, len(unique_labels)))
label_to_color = dict(zip(unique_labels, colors))

plt.figure(figsize=(10, 10))
plot_tsne(tsne_embeddings, labels, label_to_color, sensor= 'gelslim')
plt.legend(markerscale=1)
plt.title('t-SNE visualization of embeddings')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()

# %%
results_path = '/home/samanta/CMTJE/checkpoints/tactile/simclr/dataset_1_run_E400'
split = 'train'
sensor = 'both'
embeddings, labels, sensor_array = load_embeddings(results_path, split, sensor)
tsne_embeddings = apply_tsne(embeddings)

# %%
unique_labels = np.unique(labels)
colors = plt.cm.tab10(np.linspace(0, 1, len(unique_labels)))
label_to_color = dict(zip(unique_labels, colors))
g_embeddings = tsne_embeddings[sensor_array == 0]
g_labels = labels[sensor_array == 0]
b_embeddings = tsne_embeddings[sensor_array == 1]
b_labels = labels[sensor_array == 1]

plt.figure(figsize=(10, 10))
plot_tsne(g_embeddings, g_labels, label_to_color, sensor='gelslim')
plot_tsne(b_embeddings, b_labels, label_to_color, sensor='bubbles')
plt.legend(markerscale=1)
plt.title('t-SNE visualization of embeddings')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()

plt.figure(figsize=(10, 10))
plot_tsne(g_embeddings, g_labels, label_to_color, sensor='gelslim', sensor_vis=True)
plot_tsne(b_embeddings, b_labels, label_to_color, sensor='bubbles', sensor_vis=True)
plt.legend(markerscale=1)
plt.title('t-SNE visualization of embeddings')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()

plt.figure(figsize=(10, 10))
plot_tsne(g_embeddings, g_labels, label_to_color, sensor='gelslim', sensor_vis=False)
plt.legend(markerscale=1)
plt.title('t-SNE visualization of gelslims embeddings')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()

plt.figure(figsize=(10, 10))
plot_tsne(b_embeddings, b_labels, label_to_color, sensor='bubbles', sensor_vis=False)
plt.legend(markerscale=1)
plt.title('t-SNE visualization of bubbles embeddings')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()
